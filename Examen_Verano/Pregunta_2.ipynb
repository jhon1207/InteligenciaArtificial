# %%
import csv
# utilizado para manejos de directorios y rutas
import os

# Computacion vectorial y cientifica para python
import numpy as np

# Librerias para graficación (trazado de gráficos)
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D  # Necesario para graficar superficies 3D

# llama a matplotlib a embeber graficas dentro de los cuadernillos
# %matplotlib inline

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from datetime import datetime

# %%
data = pd.read_csv('/content/gastos.csv', encoding='latin-1')

# %%
print(data)
# Out:
#    Fecha;Vivienda;Alimentacion;Educacion;Transporte;Entretenimiento;Gasto por dia
# 0                           01/03/2024;20;18;8;9;5;60
# 1                           02/03/2024;19;16;6;5;6;52
# 2                           03/03/2024;19;18;5;6;6;54
# 3                           04/03/2024;19;16;8;6;5;54
# 4                         05/03/2024;20;17;10;10;6;63
# 5                          06/03/2024;20;16;5;6;10;57
# 6                         07/03/2024;18;17;10;10;9;64
# 7                          08/03/2024;19;15;7;7;10;58
# 8                          09/03/2024;19;16;10;6;7;58
# 9                          10/03/2024;18;19;10;9;8;64
# 10                          11/03/2024;18;17;7;9;7;58
# 11                         12/03/2024;18;16;5;8;10;57
# 12                         13/03/2024;18;19;5;6;10;58
# 13                          14/03/2024;20;19;5;8;7;59
# 14                          15/03/2024;18;19;9;8;5;59
# 15                         16/03/2024;20;18;10;6;9;63
# ...

# %%
display(data)
# Out:
#    Fecha;Vivienda;Alimentacion;Educacion;Transporte;Entretenimiento;Gasto por dia
# 0                           01/03/2024;20;18;8;9;5;60
# 1                           02/03/2024;19;16;6;5;6;52
# 2                           03/03/2024;19;18;5;6;6;54
# 3                           04/03/2024;19;16;8;6;5;54
# 4                         05/03/2024;20;17;10;10;6;63
# 5                          06/03/2024;20;16;5;6;10;57
# 6                         07/03/2024;18;17;10;10;9;64
# 7                          08/03/2024;19;15;7;7;10;58
# 8                          09/03/2024;19;16;10;6;7;58
# 9                          10/03/2024;18;19;10;9;8;64
# 10                          11/03/2024;18;17;7;9;7;58
# 11                         12/03/2024;18;16;5;8;10;57
# 12                         13/03/2024;18;19;5;6;10;58
# 13                          14/03/2024;20;19;5;8;7;59
# 14                          15/03/2024;18;19;9;8;5;59
# 15                         16/03/2024;20;18;10;6;9;63
# ...

# %%
data = pd.read_csv('/content/gastos.csv', encoding='latin-1', sep=";")

# %%
print(data)
# Out:
#          Fecha  Vivienda  Alimentacion  Educacion  Transporte  \
# 0   01/03/2024        20            18          8           9
# 1   02/03/2024        19            16          6           5
# 2   03/03/2024        19            18          5           6
# 3   04/03/2024        19            16          8           6
# 4   05/03/2024        20            17         10          10
# 5   06/03/2024        20            16          5           6
# 6   07/03/2024        18            17         10          10
# 7   08/03/2024        19            15          7           7
# 8   09/03/2024        19            16         10           6
# 9   10/03/2024        18            19         10           9
# 10  11/03/2024        18            17          7           9
# 11  12/03/2024        18            16          5           8
# 12  13/03/2024        18            19          5           6
# 13  14/03/2024        20            19          5           8
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Fecha            31 non-null     object
#  1   Vivienda         31 non-null     int64
#  2   Alimentacion     31 non-null     int64
#  3   Educacion        31 non-null     int64
#  4   Transporte       31 non-null     int64
#  5   Entretenimiento  31 non-null     int64
#  6   Gasto por dia    31 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.8+ KB

# %%
#variables categoricas
columnas_categoricas = data.select_dtypes(include=['object']).columns
#variables fechas
columnas_fechas = data.select_dtypes(include=['datetime64']).columns

# %%
#Procesamiento de frases o palabras
for columna in columnas_categoricas:
  le = LabelEncoder()
  data[columna] = le.fit_transform(data[columna])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Fecha            31 non-null     int64
#  1   Vivienda         31 non-null     int64
#  2   Alimentacion     31 non-null     int64
#  3   Educacion        31 non-null     int64
#  4   Transporte       31 non-null     int64
#  5   Entretenimiento  31 non-null     int64
#  6   Gasto por dia    31 non-null     int64
# dtypes: int64(7)
# memory usage: 1.8 KB

# %%
# Lectura de Datos
X = data.iloc[:, :6]
y = data.iloc[:, 6]
m = y.size

# %%
print(X)
print('*'*25)
print(y)
# Out:
#     Fecha  Vivienda  Alimentacion  Educacion  Transporte  Entretenimiento
# 0       0        20            18          8           9                5
# 1       1        19            16          6           5                6
# 2       2        19            18          5           6                6
# 3       3        19            16          8           6                5
# 4       4        20            17         10          10                6
# 5       5        20            16          5           6               10
# 6       6        18            17         10          10                9
# 7       7        19            15          7           7               10
# 8       8        19            16         10           6                7
# 9       9        18            19         10           9                8
# 10     10        18            17          7           9                7
# 11     11        18            16          5           8               10
# ...

# %%
def  featureNormalize(X):
    X_norm = X.copy()
    mu = np.zeros(X.shape[1])
    sigma = np.zeros(X.shape[1])

    mu = np.mean(X, axis = 0)
    sigma = np.std(X, axis = 0)
    X_norm = (X - mu) / sigma

    return X_norm, mu, sigma

# %%
# llama featureNormalize con los datos cargados
X_norm, mu, sigma = featureNormalize(X)

print(X)
print('Media calculada:', mu)
print('Desviación estandar calculada:', sigma)
print(X_norm)
# Out:
#     Fecha  Vivienda  Alimentacion  Educacion  Transporte  Entretenimiento
# 0       0        20            18          8           9                5
# 1       1        19            16          6           5                6
# 2       2        19            18          5           6                6
# 3       3        19            16          8           6                5
# 4       4        20            17         10          10                6
# 5       5        20            16          5           6               10
# 6       6        18            17         10          10                9
# 7       7        19            15          7           7               10
# 8       8        19            16         10           6                7
# 9       9        18            19         10           9                8
# 10     10        18            17          7           9                7
# 11     11        18            16          5           8               10
# ...

# %%
# Añade el termino de interseccion a X
# (Columna de unos para X0)
X = np.concatenate([np.ones((m, 1)), X_norm], axis=1)

# %%
print(X)
# Out:
# [[ 1.         -1.67705098  1.0660612   0.4740505   0.45164336  0.7914975
#   -1.24109084]
#  [ 1.         -1.56524758 -0.07352146 -0.80382476 -0.66843217 -1.66214474
#   -0.67529943]
#  [ 1.         -1.45344419 -0.07352146  0.4740505  -1.22846994 -1.04873418
#   -0.67529943]
#  [ 1.         -1.34164079 -0.07352146 -0.80382476  0.45164336 -1.04873418
#   -1.24109084]
#  [ 1.         -1.22983739  1.0660612  -0.16488713  1.57171889  1.40490805
#   -0.67529943]
#  [ 1.         -1.11803399  1.0660612  -0.80382476 -1.22846994 -1.04873418
#    1.58786622]
#  [ 1.         -1.00623059 -1.21310413 -0.16488713  1.57171889  1.40490805
#    1.02207481]
#  [ 1.         -0.89442719 -0.07352146 -1.44276238 -0.10839441 -0.43532362
#    1.58786622]
#  [ 1.         -0.78262379 -0.07352146 -0.80382476  1.57171889 -1.04873418
#   -0.10950801]
#  [ 1.         -0.67082039 -1.21310413  1.11298812  1.57171889  0.7914975
#    0.4562834 ]
# ...

# %%
def computeCostMulti(X, y, theta):
    # Inicializa algunos valores utiles
    m = y.shape[0] # numero de ejemplos de entrenamiento

    J = 0

    h = np.dot(X, theta)

    J = (1/(2 * m)) * np.sum(np.square(np.dot(X, theta) - y))

    return J

# %%
def gradientDescentMulti(X, y, theta, alpha, num_iters):

    # Inicializa algunos valores
    m = y.shape[0] # numero de ejemplos de entrenamiento

    # realiza una copia de theta, el cual será acutalizada por el descenso por el gradiente
    theta = theta.copy()

    J_history = []

    for i in range(num_iters):
        theta = theta - (alpha / m) * (np.dot(X, theta) - y).dot(X)
        J_history.append(computeCostMulti(X, y, theta))

    return theta, J_history

# %%
# Elegir algun valor para alpha (probar varias alternativas)
alpha = 0.0005
num_iters = 10000

# inicializa theta y ejecuta el descenso por el gradiente
theta = np.zeros(7)
theta, J_history = gradientDescentMulti(X, y, theta, alpha, num_iters)

# Grafica la convergencia del costo
pyplot.plot(np.arange(len(J_history)), J_history, lw=2)
pyplot.xlabel('Numero de iteraciones')
pyplot.ylabel('Costo J')

# Muestra los resultados del descenso por el gradiente
print('theta calculado por el descenso por el gradiente: {:s}'.format(str(theta)))

# Estimar el precio para un determinado vino de distintas caracteristicas
X_array = [1, 14, 18, 19, 9, 8, 5]
X_array[1:7] = (X_array[1:7] - mu) / sigma
price = np.dot(X_array, theta)   # Se debe cambiar esto

print('El valor predecido es (usando el descenso por el gradiente): Bs {:.4f}'.format(price))
# Out:
# theta calculado por el descenso por el gradiente: [ 5.80262202e+01 -1.52581195e-03  8.53442735e-01  1.54270680e+00
#   1.76621033e+00  1.64247712e+00  1.76196860e+00]
# El valor predecido es (usando el descenso por el gradiente): Bs 58.6007

# %%
X_array = [1, 14, 18, 19, 9, 8, 5]
X_array[1:7] = (X_array[1:7] - mu) / sigma

# %%
X_array[1:7]
# Out:
# [-0.11180339887498948,
#  -1.213104126454785,
#  1.1129881247548736,
#  1.011681122941894,
#  0.178086936439216,
#  -1.241090835659674]

# %%
def normalEqn(X, y):

    theta = np.zeros(X.shape[1])

    theta = np.dot(np.dot(np.linalg.inv(np.dot(X.T,X)),X.T),y)

    return theta

# %%
# Calcula los parametros con la ecuación de la normal
theta = normalEqn(X, y);

# Muestra los resultados optenidos a partir de la aplicación de la ecuación de la normal
print('Theta calculado a partir de la ecuación de la normal: {:s}'.format(str(theta)));

# Estimar el precio para un determinado vino

X_array = [1, 14, 18, 19, 9, 8, 5]
price = np.dot(X_array, theta)

print('Gasto predecido por dia (usando la ecuación de la normal): Bs{:.0f}'.format(price))
# Out:
# Theta calculado a partir de la ecuación de la normal: [ 5.84193548e+01 -1.77635684e-15  8.77514226e-01  1.56509800e+00
#   1.78559387e+00  1.63022952e+00  1.76743581e+00]
# Gasto predecido por dia (usando la ecuación de la normal): Bs142
